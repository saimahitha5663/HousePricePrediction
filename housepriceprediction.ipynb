# %% [markdown]
# # House Price Prediction

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
data =pd.read_csv("housing.csv")

# %%
data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income  median_house_value  \
# 0           322.0       126.0         8.3252            452600.0
# 1          2401.0      1138.0         8.3014            358500.0
# 2           496.0       177.0         7.2574            352100.0
# 3           558.0       219.0         5.6431            341300.0
# 4           565.0       259.0         3.8462            342200.0
# ...           ...         ...            ...                 ...
# 20635       845.0       330.0         1.5603             78100.0
# 20636       356.0       114.0         2.5568             77100.0
# 20637      1007.0       433.0         1.7000             92300.0
# 20638       741.0       349.0         1.8672             84700.0
# 20639      1387.0       530.0         2.3886             89400.0
#
#       ocean_proximity
# 0            NEAR BAY
# 1            NEAR BAY
# 2            NEAR BAY
# 3            NEAR BAY
# 4            NEAR BAY
# ...               ...
# 20635          INLAND
# 20636          INLAND
# 20637          INLAND
# 20638          INLAND
# 20639          INLAND
#
# [20640 rows x 10 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
data.dropna(inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20433 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20433 non-null  float64
#  1   latitude            20433 non-null  float64
#  2   housing_median_age  20433 non-null  float64
#  3   total_rooms         20433 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20433 non-null  float64
#  6   households          20433 non-null  float64
#  7   median_income       20433 non-null  float64
#  8   median_house_value  20433 non-null  float64
#  9   ocean_proximity     20433 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.7+ MB

# %%
from sklearn.model_selection import train_test_split

x= data.drop(['median_house_value'],axis=1)
y=data['median_house_value']

# %%
x
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income ocean_proximity
# 0           322.0       126.0         8.3252        NEAR BAY
# 1          2401.0      1138.0         8.3014        NEAR BAY
# 2           496.0       177.0         7.2574        NEAR BAY
# 3           558.0       219.0         5.6431        NEAR BAY
# 4           565.0       259.0         3.8462        NEAR BAY
# ...           ...         ...            ...             ...
# 20635       845.0       330.0         1.5603          INLAND
# 20636       356.0       114.0         2.5568          INLAND
# 20637      1007.0       433.0         1.7000          INLAND
# 20638       741.0       349.0         1.8672          INLAND
# 20639      1387.0       530.0         2.3886          INLAND
#
# [20433 rows x 9 columns]

# %%
y
# Out:
# 0        452600.0
# 1        358500.0
# 2        352100.0
# 3        341300.0
# 4        342200.0
#            ...
# 20635     78100.0
# 20636     77100.0
# 20637     92300.0
# 20638     84700.0
# 20639     89400.0
# Name: median_house_value, Length: 20433, dtype: float64

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
train_data=x_train.join(y_train)

# %%
train_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 8572     -118.41     33.90                39.0       2311.0           404.0
# 15108    -116.96     32.85                11.0       9724.0          1796.0
# 4166     -118.20     34.11                37.0       2040.0           611.0
# 19855    -119.45     36.35                22.0       1824.0           333.0
# 14618    -117.15     32.80                23.0       2395.0           476.0
# ...          ...       ...                 ...          ...             ...
# 1071     -121.84     39.74                43.0       2976.0           599.0
# 56       -122.28     37.82                52.0       1238.0           288.0
# 19201    -122.71     38.43                52.0       1439.0           325.0
# 1104     -121.59     39.86                14.0       1527.0           269.0
# 5556     -118.41     33.96                32.0       1044.0           219.0
#
#        population  households  median_income ocean_proximity  \
# 8572       1044.0       380.0         8.4680       <1H OCEAN
# 15108      5247.0      1777.0         4.1716       <1H OCEAN
# 4166       1698.0       545.0         1.9355       <1H OCEAN
# 19855      1076.0       282.0         2.3365          INLAND
# 14618      2284.0       488.0         3.7292      NEAR OCEAN
# ...           ...         ...            ...             ...
# 1071       1181.0       560.0         2.2621          INLAND
# 56          622.0       259.0         1.5057        NEAR BAY
# 19201       738.0       316.0         2.2262       <1H OCEAN
# 1104        665.0       261.0         2.8657          INLAND
# 5556        567.0       222.0         4.1471       <1H OCEAN
#
#        median_house_value
# 8572             472100.0
# 15108            166100.0
# 4166             166300.0
# 19855             69600.0
# 14618            146300.0
# ...                   ...
# 1071              85100.0
# 56                87500.0
# 19201            129900.0
# 1104             119600.0
# 5556             284400.0
#
# [16346 rows x 10 columns]

# %%
train_data.hist()
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %%
train_data.hist(figsize=(15,8))
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %%
plt.figure(figsize=(15,8))
sns.heatmap(train_data.corr(),annot=True,cmap="YlGnBu")
# Out:
# <Axes: >

# %%
train_data['total_rooms']=np.log(train_data['total_rooms']+1)
train_data['total_bedrooms']=np.log(train_data['total_bedrooms']+1)
train_data['population']=np.log(train_data['population']+1)
train_data['households']=np.log(train_data['households']+1)

# %%
train_data.hist(figsize=(15,8))
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %%
train_data.ocean_proximity.value_counts()
# Out:
# ocean_proximity
# <1H OCEAN     7232
# INLAND        5175
# NEAR OCEAN    2117
# NEAR BAY      1819
# ISLAND           3
# Name: count, dtype: int64

# %%
pd.get_dummies(train_data.ocean_proximity)
# Out:
#        <1H OCEAN  INLAND  ISLAND  NEAR BAY  NEAR OCEAN
# 8572        True   False   False     False       False
# 15108       True   False   False     False       False
# 4166        True   False   False     False       False
# 19855      False    True   False     False       False
# 14618      False   False   False     False        True
# ...          ...     ...     ...       ...         ...
# 1071       False    True   False     False       False
# 56         False   False   False      True       False
# 19201       True   False   False     False       False
# 1104       False    True   False     False       False
# 5556        True   False   False     False       False
#
# [16346 rows x 5 columns]

# %%
train_data.join(pd.get_dummies(train_data.ocean_proximity))
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 8572     -118.41     33.90                39.0     7.745868        6.003887
# 15108    -116.96     32.85                11.0     9.182455        7.493874
# 4166     -118.20     34.11                37.0     7.621195        6.416732
# 19855    -119.45     36.35                22.0     7.509335        5.811141
# 14618    -117.15     32.80                23.0     7.781556        6.167516
# ...          ...       ...                 ...          ...             ...
# 1071     -121.84     39.74                43.0     7.998671        6.396930
# 56       -122.28     37.82                52.0     7.122060        5.666427
# 19201    -122.71     38.43                52.0     7.272398        5.786897
# 1104     -121.59     39.86                14.0     7.331715        5.598422
# 5556     -118.41     33.96                32.0     6.951772        5.393628
#
#        population  households  median_income ocean_proximity  \
# 8572     6.951772    5.942799         8.4680       <1H OCEAN
# 15108    8.565602    7.483244         4.1716       <1H OCEAN
# 4166     7.437795    6.302619         1.9355       <1H OCEAN
# 19855    6.981935    5.645447         2.3365          INLAND
# 14618    7.734121    6.192362         3.7292      NEAR OCEAN
# ...           ...         ...            ...             ...
# 1071     7.074963    6.329721         2.2621          INLAND
# 56       6.434547    5.560682         1.5057        NEAR BAY
# 19201    6.605298    5.758902         2.2262       <1H OCEAN
# 1104     6.501290    5.568345         2.8657          INLAND
# 5556     6.342121    5.407172         4.1471       <1H OCEAN
#
#        median_house_value  <1H OCEAN  INLAND  ISLAND  NEAR BAY  NEAR OCEAN
# 8572             472100.0       True   False   False     False       False
# 15108            166100.0       True   False   False     False       False
# 4166             166300.0       True   False   False     False       False
# 19855             69600.0      False    True   False     False       False
# 14618            146300.0      False   False   False     False        True
# ...                   ...        ...     ...     ...       ...         ...
# 1071              85100.0      False    True   False     False       False
# 56                87500.0      False   False   False      True       False
# 19201            129900.0       True   False   False     False       False
# 1104             119600.0      False    True   False     False       False
# 5556             284400.0       True   False   False     False       False
#
# [16346 rows x 15 columns]

# %%
train_data=train_data.join(pd.get_dummies(train_data.ocean_proximity)).drop(['ocean_proximity'],axis=1)

# %%
train_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 8572     -118.41     33.90                39.0     7.745868        6.003887
# 15108    -116.96     32.85                11.0     9.182455        7.493874
# 4166     -118.20     34.11                37.0     7.621195        6.416732
# 19855    -119.45     36.35                22.0     7.509335        5.811141
# 14618    -117.15     32.80                23.0     7.781556        6.167516
# ...          ...       ...                 ...          ...             ...
# 1071     -121.84     39.74                43.0     7.998671        6.396930
# 56       -122.28     37.82                52.0     7.122060        5.666427
# 19201    -122.71     38.43                52.0     7.272398        5.786897
# 1104     -121.59     39.86                14.0     7.331715        5.598422
# 5556     -118.41     33.96                32.0     6.951772        5.393628
#
#        population  households  median_income  median_house_value  <1H OCEAN  \
# 8572     6.951772    5.942799         8.4680            472100.0       True
# 15108    8.565602    7.483244         4.1716            166100.0       True
# 4166     7.437795    6.302619         1.9355            166300.0       True
# 19855    6.981935    5.645447         2.3365             69600.0      False
# 14618    7.734121    6.192362         3.7292            146300.0      False
# ...           ...         ...            ...                 ...        ...
# 1071     7.074963    6.329721         2.2621             85100.0      False
# 56       6.434547    5.560682         1.5057             87500.0      False
# 19201    6.605298    5.758902         2.2262            129900.0       True
# 1104     6.501290    5.568345         2.8657            119600.0      False
# 5556     6.342121    5.407172         4.1471            284400.0       True
#
#        INLAND  ISLAND  NEAR BAY  NEAR OCEAN
# 8572    False   False     False       False
# 15108   False   False     False       False
# 4166    False   False     False       False
# 19855    True   False     False       False
# 14618   False   False     False        True
# ...       ...     ...       ...         ...
# 1071     True   False     False       False
# 56      False   False      True       False
# 19201   False   False     False       False
# 1104     True   False     False       False
# 5556    False   False     False       False
#
# [16346 rows x 14 columns]

# %%
plt.figure(figsize=(15,8))
sns.heatmap(train_data.corr(),annot=True,cmap="YlGnBu")
# Out:
# <Axes: >

# %%
plt.figure(figsize=(15,8))
sns.scatterplot(x="latitude",y="longitude",data=train_data,hue="median_house_value",palette="coolwarm")
# Out:
# <Axes: xlabel='latitude', ylabel='longitude'>

# %%
train_data['bedroom_ratio']=train_data['total_bedrooms']/train_data['total_rooms']
train_data['household_rooms']=train_data['total_rooms']/train_data['households']

# %%
plt.figure(figsize=(15,8))
sns.heatmap(train_data.corr(),annot=True,cmap="YlGnBu")
# Out:
# <Axes: >

# %%
from sklearn.linear_model import LinearRegression
x_train,y_train=train_data.drop(['median_house_value'],axis=1),train_data['median_house_value']
reg=LinearRegression()
reg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
test_data=x_train.join(y_train)
test_data['total_rooms']=np.log(test_data['total_rooms']+1)
test_data['total_bedrooms']=np.log(test_data['total_bedrooms']+1)
test_data['population']=np.log(test_data['population']+1)
test_data['households']=np.log(test_data['households']+1)

test_data=test_data.join(pd.get_dummies(test_data.ocean_proximity)).drop(['ocean_proximity'],axis=1)
test_data['bedroom_ratio']=test_data['total_bedrooms']/test_data['total_rooms']
test_data['household_rooms']=test_data['total_rooms']/test_data['households']
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_4432\4148656847.py in ?()
#       3 test_data['total_bedrooms']=np.log(test_data['total_bedrooms']+1)
#       4 test_data['population']=np.log(test_data['population']+1)
#       5 test_data['households']=np.log(test_data['households']+1)
#       6
# ----> 7 test_data=test_data.join(pd.get_dummies(test_data.ocean_proximity)).drop(['ocean_proximity'],axis=1)
#       8 test_data['bedroom_ratio']=test_data['total_bedrooms']/test_data['total_rooms']
#       9 test_data['household_rooms']=test_data['total_rooms']/test_data['households']
#
# ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    5985             and name not in self._accessors
#    5986             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'ocean_proximity'

# %%
x_test,y_test=test_data.drop(['median_house_value'],axis=1),test_data['median_house_value']

# %%
x_test
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 8572     -118.41     33.90                39.0     2.168581        1.946465
# 15108    -116.96     32.85                11.0     2.320666        2.139345
# 4166     -118.20     34.11                37.0     2.154224        2.003739
# 19855    -119.45     36.35                22.0     2.141164        1.918560
# 14618    -117.15     32.80                23.0     2.172654        1.969559
# ...          ...       ...                 ...          ...             ...
# 1071     -121.84     39.74                43.0     2.197077        2.001065
# 56       -122.28     37.82                52.0     2.094584        1.897084
# 19201    -122.71     38.43                52.0     2.112924        1.914994
# 1104     -121.59     39.86                14.0     2.120069        1.886831
# 5556     -118.41     33.96                32.0     2.073395        1.855302
#
#        population  households  median_income  <1H OCEAN  INLAND  ISLAND  \
# 8572     2.073395    1.937705         8.4680       True   False   False
# 15108    2.258174    2.138093         4.1716       True   False   False
# 4166     2.132721    1.988233         1.9355       True   False   False
# 19855    2.077181    1.893932         2.3365      False    True   False
# 14618    2.167237    1.973020         3.7292      False   False   False
# ...           ...         ...            ...        ...     ...     ...
# 1071     2.088768    1.991937         2.2621      False    True   False
# 56       2.006138    1.881095         1.5057      False   False   False
# 19201    2.028845    1.910860         2.2262       True   False   False
# 1104     2.015075    1.882262         2.8657      False    True   False
# 5556     1.993628    1.857418         4.1471       True   False   False
#
#        NEAR BAY  NEAR OCEAN  bedroom_ratio  household_rooms
# 8572      False       False       0.775108         1.303404
# 15108     False       False       0.816108         1.227069
# 4166      False       False       0.841959         1.209211
# 19855     False       False       0.773856         1.330158
# 14618     False        True       0.792581         1.256638
# ...         ...         ...            ...              ...
# 1071      False       False       0.799749         1.263669
# 56         True       False       0.795616         1.280789
# 19201     False       False       0.795734         1.262810
# 1104      False       False       0.763590         1.316678
# 5556      False       False       0.775864         1.285658
#
# [16346 rows x 15 columns]

# %%
reg.score(x_test,y_test)
# Out:
# -0.47076318617749924

# %%
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler
scaler =StandardScaler()

x_train,y_train=train_data.drop(['median_house_value'],axis=1),train_data['median_house_value']
x_train_s=scaler.fit_transform(x_train)
reg=LinearRegression()
reg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
x_test_s=scaler.transform(x_test)
